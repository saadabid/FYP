# %%
import nltk
import string

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
dataSet = pd.read_csv("intentsfile.csv", names=["inputs", "intents"])
print(dataSet)
# Out:
#                                                 inputs  \
# 0                        Kindly provide delivery time?
# 1         In how many days it will be delivered to me?
# 2                          How many days will it take?
# 3                          How many days will it take?
# 4                        And when it will be delivered
# 5                    How many days u take for delivery
# 6           Is it possible you can deliver on monday ?
# 7                                 I want it on tuesday
# 8                    How many days u take for delivery
# 9                               Kb tk place ho jye gaa
# 10          Is it possible you can deliver on monday ?
# 11                          Price kya ha or kb mily gA
# 12   Then wts the price of full set along with name...
# 13                   How many days u take for delivery
# 14                          Price kya ha or kb mily gA
# 15      How many days it will take to reach Rawalpindi
# 16                 And in how many days u will deliver
# 17                      In how many days u delivered??
# 18   I am in Lahore...In how many days you may deli...
# 19                Kitny days main delivery ho jati ha?
# 20                  Till when will i get the parcels??
# 21                                 Delivry kb tk hu gi
# 22                                      Kb tk a jay ga
# 23                               Delivery time kitna h
# 24                                deliver ktne days me
# 25          Ok brother. Plz try to deliver till Friday
# 26              How much time will it take to deliver?
# 27                      In how many days u delivered??
# 28   I am in Lahore...In how many days you may deli...
# 29               Kitny days main delivery ho jati ha?.
# ..                                                 ...
# 380          If  product not liked after delivery thn?
# 381              Is there your any shop in faisalabad?
# 382                       Size different hen dono ky .
# 383  Is se pehly wala aur ye dono same hain price d...
# 384                  Delivery free honi chaye at least
# 385  Kafi expensive hai is k elawa koi mens k lye g...
# 386                        Kindly send me a valut pics
# 387  Your store name ? Do you manufacture your own ...
# 388                             i want to be ur vendor
# 389                 Is this available in brown color??
# 390                                       contact no ?
# 391                                I want to return it
# 392  Is it pure leather or some kind of copy or stuff?
# 393                          Will u give some discount
# 394                          Kuch discount tu den bhai
# 395                            quality vise tek hai na
# 396                      Kya dress chahiye milsakta hy
# 397  Kindly plzzz make it bit early bcoz i have to ...
# 398  Is there any concession in wallet r delivery c...
# 399                   Saray wallet pe name asakta hai?
# 400  This is expensive now if I order 5 or 6 ...wha...
# 401                            Can you some discount??
# 402                          exclude delivery charges.
# 403                       Want kind of varities u have
# 404  Want to buy some gift for mu hubby will u help...
# 405                      How can i check your quality?
# 406  Do u have only card holderz and doller size wa...
# 407                             will u make on demand?
# 408                                Pls cancel my order
# 409                      so change my order to GSW-565
#
#                                              intents
# 0                                      Delivery Time
# 1                                      Delivery Time
# 2                                      Delivery Time
# 3                                      Delivery Time
# 4                                      Delivery Time
# 5                                      Delivery Time
# 6                                      Delivery Time
# 7                                      Delivery Time
# 8                                      Delivery Time
# 9                                      Delivery Time
# 10                                     Delivery Time
# 11                                     Delivery Time
# 12                                     Delivery Time
# 13                                     Delivery Time
# 14                                     Delivery Time
# 15                                     Delivery Time
# 16                                     Delivery Time
# 17                                     Delivery Time
# 18                                     Delivery Time
# 19                                     Delivery Time
# 20                                     Delivery Time
# 21                                     Delivery Time
# 22                                     Delivery Time
# 23                                     Delivery Time
# 24                                     Delivery Time
# 25                                     Delivery Time
# 26                                     Delivery Time
# 27                                     Delivery Time
# 28                                     Delivery Time
# 29                                     Delivery Time
# ..                                               ...
# 380  imp questions/ queries to be answered by goshop
# 381  imp questions/ queries to be answered by goshop
# 382  imp questions/ queries to be answered by goshop
# 383  imp questions/ queries to be answered by goshop
# 384  imp questions/ queries to be answered by goshop
# 385  imp questions/ queries to be answered by goshop
# 386  imp questions/ queries to be answered by goshop
# 387  imp questions/ queries to be answered by goshop
# 388  imp questions/ queries to be answered by goshop
# 389  imp questions/ queries to be answered by goshop
# 390  imp questions/ queries to be answered by goshop
# 391  imp questions/ queries to be answered by goshop
# 392  imp questions/ queries to be answered by goshop
# 393  imp questions/ queries to be answered by goshop
# 394  imp questions/ queries to be answered by goshop
# 395  imp questions/ queries to be answered by goshop
# 396  imp questions/ queries to be answered by goshop
# 397  imp questions/ queries to be answered by goshop
# 398  imp questions/ queries to be answered by goshop
# 399  imp questions/ queries to be answered by goshop
# 400  imp questions/ queries to be answered by goshop
# 401  imp questions/ queries to be answered by goshop
# 402  imp questions/ queries to be answered by goshop
# 403  imp questions/ queries to be answered by goshop
# 404  imp questions/ queries to be answered by goshop
# 405  imp questions/ queries to be answered by goshop
# 406  imp questions/ queries to be answered by goshop
# 407  imp questions/ queries to be answered by goshop
# 408                               Order cancellation
# 409                                Order Replacement
#
# [410 rows x 2 columns]

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
dataSet['inputs'] = dataSet['inputs'].apply(text_process)

# %%
dataSet.head()
# Out:
#                               inputs        intents
# 0  [Kindly, provide, delivery, time]  Delivery Time
# 1            [many, days, delivered]  Delivery Time
# 2                 [many, days, take]  Delivery Time
# 3                 [many, days, take]  Delivery Time
# 4                        [delivered]  Delivery Time

# %%
# Might take awhile...
bow_transformer = CountVectorizer(analyzer=text_process).fit(dataSet['inputs'])

# Print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 338

# %%
dataset3 = dataSet['inputs'][3]
print(dataset3)
# Out:
# ['many', 'days', 'take']

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=text_process)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
msg_train, msg_test, label_train, label_test = \
train_test_split(dataSet['inputs'], dataSet['intents'], test_size=0.3)

print(len(msg_train), len(msg_test), len(msg_train) + len(msg_test))
# Out:
# 287 123 410

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer=<function text_process at 0x00000036F777F488>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preprocesso...f=False, use_idf=True)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(msg_test)

# %%
predictions = pipeline.predict(["what is delivery charges ?"])

# %%
type(msg_test)
# Out:
# pandas.core.series.Series

# %%
print(predictions)
# Out:
# ['Price' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Delivery Time'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Price' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Delivery Time' 'Delivery Charges' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Price' 'Delivery Time' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Delivery Charges' 'Order' 'Order' 'Order' 'Order'
#  'Price' 'Price' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Delivery Time' 'Order' 'Order' 'Order' 'Order' 'Delivery Time' 'Order'
#  'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order' 'Order'
#  'Order' 'Order' 'Order' 'Delivery Time']

# %%
print(classification_report(predictions,label_test))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                Delivery Charges       0.33      0.50      0.40         2
#                                 Delivery Method       0.00      0.00      0.00         0
#                                   Delivery Time       0.15      0.67      0.24         6
#                                           Order       0.96      0.23      0.37       110
#                                    Order Status       0.00      0.00      0.00         0
#                              Order cancellation       0.00      0.00      0.00         0
#                                           Price       0.20      0.80      0.32         5
#                                      Total Cost       0.00      0.00      0.00         0
# imp questions/ queries to be answered by goshop       0.00      0.00      0.00         0
#
#                                     avg / total       0.88      0.28      0.36       123
# C:\Users\Muhammad Saad\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
predictions
# Out:
# array(['Price', 'Price', 'Price', 'Price', 'Total Cost', 'Price', 'Price',
#        'Price', 'Price', 'Price', 'Price', 'Price', 'Price', 'Price',
#        'Price', 'Price', 'Price', 'Price', 'Price', 'Price', 'Price',
#        'Price', 'Price', 'Price', 'Delivery Time', 'Price'],
#       dtype='<U16')

# %%
msg_test
# Out:
# 305                                           [discount]
# 215                   [u, send, original, pic, GSW, 504]
# 237                                               [much]
# 380                      [product, liked, delivery, thn]
# 186                           [Exchange, return, policy]
# 132                                               [want]
# 1                                [many, days, delivered]
# 109              [Prices, delivery, charges, n, karachi]
# 264                        [Ok, rough, idea, abt, price]
# 2                                     [many, days, take]
# 375                                 [guarattee, leather]
# 295                    [price, brown, wallet, name, itt]
# 377                                            [genuine]
# 4                                            [delivered]
# 61                                         [Ok, kab, ga]
# 409                              [change, order, GSW565]
# 198             [Different, sizes, one, size, Available]
# 272              [Normal, wallet, keychain, name, price]
# 58                                           [Ok, reach]
# 396                  [Kya, dress, chahiye, milsakta, hy]
# 60                                     [Kab, ga, parsal]
# 387                  [store, name, manufacture, Product]
# 48                      [2, din, delivered, ho, jai, ga]
# 402                         [exclude, delivery, charges]
# 239                                       [Whats, price]
# 115                                           [Tcs, lcs]
# 214                            [total, price, gift, box]
# 14                        [Price, kya, ha, kb, mily, gA]
# 393                                  [u, give, discount]
# 350                           [Ye, kon, sa, leather, hy]
#                              ...
# 274    [HellowI, want, know, write, name, volet, yes,...
# 166              [Hello, id, like, place, order, gsw514]
# 318                         [Ok, total, amount, hv, pay]
# 364                                     [850, expensive]
# 182                                          [Thickness]
# 43                              [u, deliver, many, days]
# 268                                  [Hello, tel, price]
# 254    [12, items, please, inform, Prise, Price, orig...
# 204                                            [picture]
# 174                                       [place, order]
# 29           [Kitny, days, main, delivery, ho, jati, ha]
# 77          [u, snd, pictrs, gsw, 547nd, delivery, days]
# 365                                     [Price, n, pics]
# 366                       [Aoa, u, cheque, book, covers]
# 221                 [Havent, got, delivery, yet, arrive]
# 280                                        [much, costs]
# 235                [representative, didnt, contact, yet]
# 261                                    [Gse, 535, price]
# 171                              [want, purchase, purse]
# 9                          [Kb, tk, place, ho, jye, gaa]
# 349                           [Acha, hta, hyna, quality]
# 390                                            [contact]
# 85                                 [many, days, recieve]
# 385    [Kafi, expensive, hai, k, elawa, koi, mens, k,...
# 395                        [quality, vise, tek, hai, na]
# 91                         [Delivery, charges, included]
# 97                                   [pay, TCS, charges]
# 16                              [many, days, u, deliver]
# 11                        [Price, kya, ha, kb, mily, gA]
# 382                     [Size, different, hen, dono, ky]
# Name: inputs, dtype: object

# %%
label_test
# Out:
# 360    imp questions/ queries to be answered by goshop
# 101                                   Delivery Charges
# 351    imp questions/ queries to be answered by goshop
# 186                                              Order
# 8                                        Delivery Time
# 395    imp questions/ queries to be answered by goshop
# 226                                       Order Status
# 116                                    Delivery Method
# 379    imp questions/ queries to be answered by goshop
# 104                                   Delivery Charges
# 86                                       Delivery Time
# 295                                              Price
# 54                                       Delivery Time
# 313                                         Total Cost
# 329                                         Total Cost
# 202                                              Order
# 191                                              Order
# 150                                              Order
# 187                                              Order
# 387    imp questions/ queries to be answered by goshop
# 253                                              Price
# 95                                    Delivery Charges
# 335                                         Total Cost
# 12                                       Delivery Time
# 156                                              Order
# 122                                     Payment Method
# 366    imp questions/ queries to be answered by goshop
# 225                                       Order Status
# 261                                              Price
# 288                                              Price
#                             ...
# 338                                         Total Cost
# 135                                              Order
# 384    imp questions/ queries to be answered by goshop
# 391    imp questions/ queries to be answered by goshop
# 145                                              Order
# 256                                              Price
# 89                                    Delivery Charges
# 133                                              Order
# 326                                         Total Cost
# 247                                              Price
# 213                                              Order
# 176                                              Order
# 192                                              Order
# 328                                         Total Cost
# 193                                              Order
# 63                                       Delivery Time
# 363    imp questions/ queries to be answered by goshop
# 36                                       Delivery Time
# 272                                              Price
# 260                                              Price
# 123                                     Payment Method
# 148                                              Order
# 314                                         Total Cost
# 71                                       Delivery Time
# 15                                       Delivery Time
# 107                                   Delivery Charges
# 200                                              Order
# 361    imp questions/ queries to be answered by goshop
# 50                                       Delivery Time
# 252                                              Price
# Name: intents, dtype: object

# %%
labelTestDF = pd.DataFrame(label_test)
predictionsDF = pd.DataFrame(predictions)
print(labelTestDF.shape)
print(predictionsDF.shape)
# Out:
# (123, 1)
# (123, 1)

# %%
labelTestDF
# Out:
#                                              intents
# 360  imp questions/ queries to be answered by goshop
# 101                                 Delivery Charges
# 351  imp questions/ queries to be answered by goshop
# 186                                            Order
# 8                                      Delivery Time
# 395  imp questions/ queries to be answered by goshop
# 226                                     Order Status
# 116                                  Delivery Method
# 379  imp questions/ queries to be answered by goshop
# 104                                 Delivery Charges
# 86                                     Delivery Time
# 295                                            Price
# 54                                     Delivery Time
# 313                                       Total Cost
# 329                                       Total Cost
# 202                                            Order
# 191                                            Order
# 150                                            Order
# 187                                            Order
# 387  imp questions/ queries to be answered by goshop
# 253                                            Price
# 95                                  Delivery Charges
# 335                                       Total Cost
# 12                                     Delivery Time
# 156                                            Order
# 122                                   Payment Method
# 366  imp questions/ queries to be answered by goshop
# 225                                     Order Status
# 261                                            Price
# 288                                            Price
# ..                                               ...
# 338                                       Total Cost
# 135                                            Order
# 384  imp questions/ queries to be answered by goshop
# 391  imp questions/ queries to be answered by goshop
# 145                                            Order
# 256                                            Price
# 89                                  Delivery Charges
# 133                                            Order
# 326                                       Total Cost
# 247                                            Price
# 213                                            Order
# 176                                            Order
# 192                                            Order
# 328                                       Total Cost
# 193                                            Order
# 63                                     Delivery Time
# 363  imp questions/ queries to be answered by goshop
# 36                                     Delivery Time
# 272                                            Price
# 260                                            Price
# 123                                   Payment Method
# 148                                            Order
# 314                                       Total Cost
# 71                                     Delivery Time
# 15                                     Delivery Time
# 107                                 Delivery Charges
# 200                                            Order
# 361  imp questions/ queries to be answered by goshop
# 50                                     Delivery Time
# 252                                            Price
#
# [123 rows x 1 columns]

# %%
predictionsDF
# Out:
#                  0
# 0            Order
# 1            Order
# 2            Order
# 3            Order
# 4    Delivery Time
# 5            Order
# 6            Order
# 7            Order
# 8            Order
# 9            Order
# 10   Delivery Time
# 11           Order
# 12           Order
# 13           Order
# 14           Order
# 15           Order
# 16           Order
# 17           Order
# 18           Order
# 19           Order
# 20           Order
# 21           Order
# 22           Order
# 23           Order
# 24           Order
# 25           Order
# 26           Order
# 27           Order
# 28           Order
# 29           Order
# ..             ...
# 93           Order
# 94           Order
# 95           Order
# 96           Order
# 97           Order
# 98           Price
# 99           Order
# 100          Order
# 101          Order
# 102          Price
# 103          Order
# 104          Order
# 105          Order
# 106          Order
# 107          Order
# 108          Order
# 109          Order
# 110          Order
# 111          Order
# 112          Order
# 113          Order
# 114          Order
# 115          Order
# 116  Delivery Time
# 117          Order
# 118          Order
# 119          Order
# 120          Order
# 121          Order
# 122          Order
#
# [123 rows x 1 columns]

# %%
result = pd.concat([predictionsDF[0], labelTestDF1['intents'], testmDF['inputs']], axis=1, ignore_index=False)
result.head(25)
# Out:
#                 0                                          intents  \
# 0           Price                                            Price
# 1           Order                                    Delivery Time
# 2           Order                                            Order
# 3           Order                                    Delivery Time
# 4           Order  imp questions/ queries to be answered by goshop
# 5           Order  imp questions/ queries to be answered by goshop
# 6           Order                                            Order
# 7   Delivery Time                                    Delivery Time
# 8           Order                                    Delivery Time
# 9           Order                                    Delivery Time
# 10          Order                                            Order
# 11          Order  imp questions/ queries to be answered by goshop
# 12          Order                                            Price
# 13          Order  imp questions/ queries to be answered by goshop
# 14          Order                                            Price
# 15          Order  imp questions/ queries to be answered by goshop
# 16          Order  imp questions/ queries to be answered by goshop
# 17          Order                                            Order
# 18          Price                                            Price
# 19          Order                                    Delivery Time
# 20          Order                                    Delivery Time
# 21          Order  imp questions/ queries to be answered by goshop
# 22          Order  imp questions/ queries to be answered by goshop
# 23          Order                                            Order
# 24          Order  imp questions/ queries to be answered by goshop
#
#                              inputs
# 0                               NaN
# 1           [many, days, delivered]
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5   [many, days, u, take, delivery]
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11   [Price, kya, ha, kb, mily, gA]
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16         [many, days, u, deliver]
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20             [Till, get, parcels]
# 21                              NaN
# 22                [Kb, tk, jay, ga]
# 23                              NaN
# 24                              NaN

# %%
res1 = pd.DataFrame(columns=["pred", "label"], data=[predictionsDF[0], labelTestDF['intents']], index=None)

# %%
res1.head()
# Out:
#          pred  label
# 0         NaN    NaN
# intents   NaN    NaN

# %%
print(result)
# Out:
#                                                    0  \
# 0                                      Delivery Time
# 1                                      Delivery Time
# 2                                      Delivery Time
# 3                                      Delivery Time
# 4                                      Delivery Time
# 5                                      Delivery Time
# 6                                      Delivery Time
# 7                                              Price
# 8                                      Delivery Time
# 9                                      Delivery Time
# 10                                     Delivery Time
# 11                                     Delivery Time
# 12                                     Delivery Time
# 13   imp questions/ queries to be answered by goshop
# 14                                     Delivery Time
# 15                                     Delivery Time
# 16                                     Delivery Time
# 17                                     Delivery Time
# 18                                     Delivery Time
# 19                                             Order
# 20                                     Delivery Time
# 21                                     Delivery Time
# 22                                     Delivery Time
# 23                                             Order
# 24                                     Delivery Time
# 25                                     Delivery Time
# 26                                     Delivery Time
# 27                                     Delivery Time
# 28                                     Delivery Time
# 29                                     Delivery Time
# ..                                               ...
# 93                                     Delivery Time
# 94                                     Delivery Time
# 95                                             Order
# 96                                             Price
# 97                                     Delivery Time
# 98                                     Delivery Time
# 99                                     Delivery Time
# 100                                    Delivery Time
# 101                                    Delivery Time
# 102                                    Delivery Time
# 103                                            Order
# 104                                    Delivery Time
# 105                                    Delivery Time
# 106                                    Delivery Time
# 107                                    Delivery Time
# 108                                    Delivery Time
# 109                                    Delivery Time
# 110                                    Delivery Time
# 111                                    Delivery Time
# 112                                    Delivery Time
# 113                                    Delivery Time
# 114                                            Price
# 115  imp questions/ queries to be answered by goshop
# 116                                    Delivery Time
# 117                                    Delivery Time
# 118                                    Delivery Time
# 119                                    Delivery Time
# 120                                    Delivery Time
# 121                                    Delivery Time
# 122                                    Delivery Time
#
#                                              intents  \
# 0                                         Total Cost
# 1                                      Delivery Time
# 2                                      Delivery Time
# 3    imp questions/ queries to be answered by goshop
# 4                                              Order
# 5    imp questions/ queries to be answered by goshop
# 6    imp questions/ queries to be answered by goshop
# 7                                              Price
# 8    imp questions/ queries to be answered by goshop
# 9                                         Total Cost
# 10                                  Delivery Charges
# 11                                             Order
# 12                                     Delivery Time
# 13                                             Price
# 14                                          Discount
# 15   imp questions/ queries to be answered by goshop
# 16                                             Price
# 17   imp questions/ queries to be answered by goshop
# 18                                             Order
# 19                                             Price
# 20                                             Order
# 21                                        Total Cost
# 22                                             Price
# 23   imp questions/ queries to be answered by goshop
# 24                                             Order
# 25                                             Order
# 26                                             Order
# 27                                             Order
# 28                                Order cancellation
# 29                                             Price
# ..                                               ...
# 93                                 Order Replacement
# 94                                             Order
# 95   imp questions/ queries to be answered by goshop
# 96                                        Total Cost
# 97                                             Price
# 98                                     Delivery Time
# 99                                      Order Status
# 100  imp questions/ queries to be answered by goshop
# 101                                            Order
# 102                                    Delivery Time
# 103                                            Order
# 104                                     Order Status
# 105                                    Delivery Time
# 106                                       Total Cost
# 107                                  Delivery Method
# 108                                     Order Status
# 109                                   Payment Method
# 110                                            Price
# 111  imp questions/ queries to be answered by goshop
# 112                                       Total Cost
# 113                                       Total Cost
# 114                                            Price
# 115                                            Price
# 116                                            Order
# 117                                   Payment Method
# 118                                    Delivery Time
# 119                                            Order
# 120                                            Order
# 121                                            Order
# 122                                            Price
#
#                                                 inputs
# 0                                         [difference]
# 1                                  [delivery, charges]
# 2                          [u, leather, jackets, well]
# 3                           [Exchange, return, policy]
# 4                      [many, days, u, take, delivery]
# 5                        [quality, vise, tek, hai, na]
# 6                               [u, dispatched, order]
# 7                                [Procedure, delivery]
# 8                                           [Discount]
# 9                                  [delivery, charges]
# 10                               [many, days, deliver]
# 11                   [price, brown, wallet, name, itt]
# 12                             [kub, tuk, mil, jy, ga]
# 13                                 [Total, price, pls]
# 14      [u, gin, final, pirce, wid, delivery, charges]
# 15        [u, made, purse, one, side, size, atm, card]
# 16                                        [send, pics]
# 17   [want, order, brown, one, name, Hamza, Chohano...
# 18                     [u, hav, article, bold, curves]
# 19                 [store, name, manufacture, Product]
# 20                                         [much, one]
# 21      [u, gin, final, pirce, wid, delivery, charges]
# 22                       [one, price, total, delivery]
# 23   [wts, price, full, set, along, name, Please, c...
# 24   [want, order, gift, box, set, wallet, keychain...
# 25                                    [Cash, delivery]
# 26                      [Aoa, u, cheque, book, covers]
# 27   [Havent, received, parcel, order, placed, sinc...
# 28                                   [Gse, 535, price]
# 29                                 [delivery, charges]
# ..                                                 ...
# 93                    [much, pay, dlvry, chargewallet]
# 94                            [want, wallet, keychain]
# 95                [Delivery, free, honi, chaye, least]
# 96                                      [want, return]
# 97            [want, customize, wallet, keychain, set]
# 98                                    [Price, n, pics]
# 99                                 [Delivery, charges]
# 100                                 [want, order, one]
# 101                              [Tell, total, amount]
# 102                                     [Whats, price]
# 103                               [name, print, items]
# 104                                            [Noted]
# 105                   [b, font, color, size, n, style]
# 106                           [u, give, total, amount]
# 107                              [R, u, based, lahore]
# 108                                      [Ok, deliver]
# 109                               [product, code, 538]
# 110                                 [Kb, tk, mily, ga]
# 111            [Normal, wallet, keychain, name, price]
# 112                                        [much, one]
# 113                                       [Hw, pay, u]
# 114                                   [want, 3, words]
# 115                                [much, total, cost]
# 116                                  [Okk, many, days]
# 117              [many, days, take, reach, Rawalpindi]
# 118                                [delivery, charges]
# 119                                           [Sample]
# 120                               [2, word, font, Plz]
# 121  [Kindly, plzzz, make, bit, early, bcoz, take, ...
# 122                         [Kindly, tell, da, amount]
#
# [123 rows x 3 columns]

# %%
labelTestDF1 = labelTestDF.reset_index()

# %%
labelTestDF1 = labelTestDF.reset_index()
# Out:
#    index                                          intents
# 0    257                                            Price
# 1     77                                    Delivery Time
# 2    126                                            Order
# 3     54                                    Delivery Time
# 4    359  imp questions/ queries to be answered by goshop

# %%
testmDF = pd.DataFrame(msg_test)
testmDF.head()
# Out:
#                                            inputs
# 257                               [price, wallet]
# 77   [u, snd, pictrs, gsw, 547nd, delivery, days]
# 126                               [want, product]
# 54                        [kub, tuk, mil, jy, ga]
# 359                                           [u]

# %%
testmDF = testmDF.reset_index()

# %%
testmDF.head()
# Out:
#    index                                        inputs
# 0    257                               [price, wallet]
# 1     77  [u, snd, pictrs, gsw, 547nd, delivery, days]
# 2    126                               [want, product]
# 3     54                       [kub, tuk, mil, jy, ga]
# 4    359                                           [u]
